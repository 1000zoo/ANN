# %% [markdown]
# ex1

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=False)
k=0
for train_index, valid_index in kf.split(train_images):
  X_train, label_train = train_images[train_index], train_labels[train_index]
  X_valid, label_valid = train_images[valid_index], train_labels[valid_index]
  print(k,"th fold:")
  print(X_train.shape)
  print(X_valid.shape)
  k+=1
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# 0 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# 1 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# 2 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# 3 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# 4 th fold:
# (48000, 28, 28)
# (12000, 28, 28)

# %% [markdown]
# ex2 (for loop 내부 코드추가)

# %%
from tensorflow.keras.datasets import mnist
import collections

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=False)
k=0
for train_index, valid_index in kf.split(train_images):
  X_train, label_train = train_images[train_index], train_labels[train_index]
  X_valid, label_valid = train_images[valid_index], train_labels[valid_index]
  print(k,"th fold:")
  print(X_train.shape)
  print(X_valid.shape)
  print(collections.Counter(label_train))
  k+=1
# Out:
# 0 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5391, 7: 4986, 3: 4903, 2: 4782, 9: 4756, 8: 4724, 0: 4717, 6: 4710, 4: 4658, 5: 4373})
# 1 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5361, 7: 5055, 3: 4872, 2: 4787, 6: 4756, 0: 4748, 9: 4731, 8: 4686, 4: 4679, 5: 4325})
# 2 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5361, 7: 5033, 3: 4928, 0: 4770, 2: 4763, 9: 4736, 6: 4721, 4: 4682, 8: 4671, 5: 4335})
# 3 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5385, 7: 5018, 3: 4932, 9: 4771, 2: 4738, 6: 4737, 0: 4728, 4: 4694, 8: 4670, 5: 4327})
# 4 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5470, 7: 4968, 3: 4889, 9: 4802, 2: 4762, 6: 4748, 0: 4729, 4: 4655, 8: 4653, 5: 4324})

# %% [markdown]
# ex3

# %%
from tensorflow.keras.datasets import mnist
import collections

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=False)
k=0
for train_index, valid_index in skf.split(train_images, train_labels):
  X_train, label_train = train_images[train_index], train_labels[train_index]
  X_valid, label_valid = train_images[valid_index], train_labels[valid_index]
  print(k,"th fold:")
  print(X_train.shape)
  print(X_valid.shape)
  print(collections.Counter(label_train))
  k+=1
# Out:
# 0 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4904, 2: 4767, 9: 4759, 0: 4739, 6: 4735, 8: 4681, 4: 4673, 5: 4336})
# 1 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5393, 7: 5012, 3: 4905, 2: 4767, 9: 4759, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# 2 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5393, 7: 5012, 3: 4905, 2: 4766, 9: 4760, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# 3 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4905, 2: 4766, 9: 4759, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# 4 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4905, 2: 4766, 9: 4759, 0: 4739, 6: 4735, 8: 4680, 4: 4673, 5: 4337})

# %% [markdown]
# ex4

# %%
from tensorflow.keras.datasets import mnist
import collections

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=False)
k=0
for train_index, valid_index in skf.split(train_images, train_labels):
  X_train, label_train = train_images[train_index], train_labels[train_index]
  X_valid, label_valid = train_images[valid_index], train_labels[valid_index]
  print(k,"th fold:")
  print(X_train.shape)
  print(X_valid.shape)
  print(collections.Counter(label_train))
  print(label_train[0:10])
  k+=1
# Out:
# 0 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4904, 2: 4767, 9: 4759, 0: 4739, 6: 4735, 8: 4681, 4: 4673, 5: 4336})
# [7 7 7 7 7 7 6 7 7 6]
# 1 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5393, 7: 5012, 3: 4905, 2: 4767, 9: 4759, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# [5 0 4 1 9 2 1 3 1 4]
# 2 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5393, 7: 5012, 3: 4905, 2: 4766, 9: 4760, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# [5 0 4 1 9 2 1 3 1 4]
# 3 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4905, 2: 4766, 9: 4759, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# [5 0 4 1 9 2 1 3 1 4]
# 4 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4905, 2: 4766, 9: 4759, 0: 4739, 6: 4735, 8: 4680, 4: 4673, 5: 4337})
# [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# ex5

# %%
from tensorflow.keras.datasets import mnist
import collections

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=True)
k=0
for train_index, valid_index in skf.split(train_images, train_labels):
  X_train, label_train = train_images[train_index], train_labels[train_index]
  X_valid, label_valid = train_images[valid_index], train_labels[valid_index]
  print(k,"th fold:")
  print(X_train.shape)
  print(X_valid.shape)
  print(collections.Counter(label_train))
  print(label_train[0:10])
  k+=1
# Out:
# 0 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4904, 2: 4767, 9: 4759, 0: 4739, 6: 4735, 8: 4681, 4: 4673, 5: 4336})
# [0 4 9 2 1 1 4 3 6 1]
# 1 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5393, 7: 5012, 3: 4905, 2: 4767, 9: 4759, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# [5 4 1 9 2 3 4 3 5 3]
# 2 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5393, 7: 5012, 3: 4905, 2: 4766, 9: 4760, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# [5 0 4 1 9 2 1 3 1 3]
# 3 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4905, 2: 4766, 9: 4759, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# [5 0 1 1 3 1 4 3 5 1]
# 4 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4905, 2: 4766, 9: 4759, 0: 4739, 6: 4735, 8: 4680, 4: 4673, 5: 4337})
# [5 0 4 1 9 2 1 3 1 4]

# %%
from tensorflow.keras.datasets import mnist
import collections

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=True)
k=0
for train_index, valid_index in skf.split(train_images, train_labels):
  X_train, label_train = train_images[train_index], train_labels[train_index]
  X_valid, label_valid = train_images[valid_index], train_labels[valid_index]
  print(k,"th fold:")
  print(X_train.shape)
  print(X_valid.shape)
  print(collections.Counter(label_train))
  print(label_train[0:10])
  k+=1
# Out:
# 0 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4904, 2: 4767, 9: 4759, 0: 4739, 6: 4735, 8: 4681, 4: 4673, 5: 4336})
# Counter({1: 1348, 7: 1253, 3: 1227, 2: 1191, 9: 1190, 0: 1184, 6: 1183, 8: 1170, 4: 1169, 5: 1085})
# [5 0 4 1 9 2 1 3 1 4]
# 1 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5393, 7: 5012, 3: 4905, 2: 4767, 9: 4759, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# Counter({1: 1349, 7: 1253, 3: 1226, 2: 1191, 9: 1190, 0: 1185, 6: 1184, 8: 1170, 4: 1168, 5: 1084})
# [0 4 1 9 2 1 3 1 4 3]
# 2 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5393, 7: 5012, 3: 4905, 2: 4766, 9: 4760, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# Counter({1: 1349, 7: 1253, 3: 1226, 2: 1192, 9: 1189, 0: 1185, 6: 1184, 8: 1170, 4: 1168, 5: 1084})
# [5 4 1 9 2 1 3 1 4 3]
# 3 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4905, 2: 4766, 9: 4759, 0: 4738, 6: 4734, 8: 4681, 4: 4674, 5: 4337})
# Counter({1: 1348, 7: 1253, 3: 1226, 2: 1192, 9: 1190, 0: 1185, 6: 1184, 8: 1170, 4: 1168, 5: 1084})
# [5 0 4 9 2 1 4 5 3 7]
# 4 th fold:
# (48000, 28, 28)
# (12000, 28, 28)
# Counter({1: 5394, 7: 5012, 3: 4905, 2: 4766, 9: 4759, 0: 4739, 6: 4735, 8: 4680, 4: 4673, 5: 4337})
# Counter({1: 1348, 7: 1253, 3: 1226, 2: 1192, 9: 1190, 0: 1184, 6: 1183, 8: 1171, 4: 1169, 5: 1084})
# [5 0 1 3 1 3 5 3 6 1]
